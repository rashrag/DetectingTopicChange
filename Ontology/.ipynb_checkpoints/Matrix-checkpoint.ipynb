# %%
from textrazor import TextRazor
import re
import nltk
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
phraseDict = {'Jagdstaffel': ['Oswald Boelcke', 'Jagdstaffel', 'Jagdgeschwader 1 (World War I)', 'Dogfight', 'Bloody April', 'Synchronization gear', 'Aviation', 'World War I', 'Sopwith Camel', 'Fokker Dr.I', 'Max Immelmann', 'Anthony Fokker', 'Jagdstaffel 2', 'Cavalry', 'National security', 'Triplane', 'Aerial warfare', 'Jagdstaffel 11', 'Conflicts', 'Reconnaissance'], 'Air forces': ['Air forces', 'Air force', 'Royal Air Force'], 'No. 209 Squadron RAF': ['No. 209 Squadron RAF'], 'Military': ['Manfred von Richthofen', 'Fighter aircraft', 'Luftstreitkräfte', 'Cedric Popkin', 'Flying ace', 'Military', 'Military science', 'Military forces', 'Warfare', 'Military aviation', 'War', 'Aeronautics', 'Trench warfare', 'Aircraft', 'International security', 'Sopwith Aviation Company', 'Lanoe Hawker', 'Airplane', 'Aerospace engineering', 'Combat', 'Royal Flying Corps', 'Military organization', 'Violent conflict', 'Military operations'], 'Imperial German Army Air Service': ['Imperial German Army Air Service'], 'Roy Brown (RAF officer)': ['Roy Brown (RAF officer)']}

# %%
## Functions Definitions ##

def get_top_relevant_topics(response, thresh_score):
    top_relevant_topics = []
    topics = []
    topics = response.topics()
    top_relevant_topics = [topic for topic in topics if topic.score > thresh_score]

    return top_relevant_topics

# %%
df = pd.DataFrame(index=phraseDict, columns=range(1,len(sentences)+1))
df = df.fillna(0) # with 0s rather than NaNs

# %%
def buildArray(txtFile, clusterdict,windowsize):
    ####################Done once##############################################################################
    import winsound
    duration = 2000  # millisecond
    freq = 440  # Hz
    import math
    import csv
    from textrazor import TextRazorAnalysisException
    from urllib.error import HTTPError
    inFile = open(txtFile, encoding='utf8').read()
    tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')
    sentences = tokenizer.tokenize(inFile)
    num_columns = math.ceil(len(sentences)/windowsize) + 1
    df = pd.DataFrame(index=phraseDict, columns=range(1,num_columns))
    df = df.fillna(0)
    
    
    sentence_num=1
    no_cluster_dict = {}
    textrazor_key = "eb2a5954577a28b1ba8a97005281289493eee48179d2ac1883b685e6"#"eb2a5954577a28b1ba8a97005281289493eee48179d2ac1883b685e6"
    ###########################################################################################################
    
    for i in range(0,len(sentences),windowsize):
        #while i in range(0,len(sentences),windowsize):
        try:
            print("i = ", i)
            client = TextRazor(textrazor_key, extractors=["topics"])
            row=0
            sentence = str(sentences[i:i+windowsize])
            print(i , sentence)
            topicDict = {}
            response = client.analyze(sentence)
            topics = get_top_relevant_topics(response, 0.5)
            cluster_val = 0
            for topic in topics:
                print(" ", topic.label, topic.score)
                topicDict.update({topic.label: topic.score})
            for key in clusterdict:
                print('Phrase Number =',row)
                phrase = clusterdict.get(key)
                print(clusterdict.get(key))
                val = 0
                
                sumProb = 0
                numMatch = 0
                for topicKey in topicDict:
                    sumProb += topicDict.get(topicKey)
                    #print('Topic Number = ',j)
                    #print(topicKey, topicDict.get(topicKey))
                    if topicKey in phrase:
                        print(topicKey, topicDict.get(topicKey))
                        val += topicDict.get(topicKey)
                        numMatch +=1
                print('val =', val)
                print('row =', row, 'sentence_num =', sentence_num)
                if numMatch!=0:
                    df[sentence_num].iloc[row] = val/numMatch
                else:
                    df[sentence_num].iloc[row] = val/1
                cluster_val += val
                row+= 1
            if cluster_val == 0:
                no_cluster_dict.update({sentence_num: topicDict})
            sentence_num += 1

        except (HTTPError, TextRazorAnalysisException) as e:
            
            winsound.MessageBeep(0)
            print("Error on " ,textrazor_key)
            textrazor_key = "5fdb0f64097c21849b8a9345fd8df3df5730ecfca4ab1c4e01a285b0"
            print("i = ", i)
            #i = i - windowsize
            #print("i = ", i)
            print(e)
            continue
    df_csv_file = 'output_ws'+str(windowsize)+ '.csv'
    no_cluster_csv_file = 'no_cluster_dict_ws'+str(windowsize)+ '.csv'
    print("Output files:", df_csv_file, no_cluster_csv_file)
    df.to_csv(df_csv_file)
    with open(no_cluster_csv_file, 'w') as csv_file:
        writer_dict = csv.writer(csv_file)
        for key, value in no_cluster_dict.items():
            writer_dict.writerow([key, value])
    winsound.Beep(freq, duration)
    return df

# %%
def hardMax(df):
    df_max = pd.DataFrame(0, columns=df.columns, index=df.index)

    for column in df_max:
        index = df[column].idxmax()
        if df.loc[index,column]!=0:
            df_max.loc[index,column] = 1
    return df_max

# %% [markdown]
# ## Plot facet plots and hardmax plots for windowsizes 1 to 10

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from ggplot import *

for i in range(1,11):
    print (i)
    
    my_df_array = buildArray("textFile1", phraseDict, i)
    dfmax = hardMax(my_df_array)

    df_new_Array = my_df_array
    df_new_Array["id"] = df_new_Array.index
    df_new_Array = pd.melt(df_new_Array, id_vars='id', value_vars=range(1,len(df_new_Array.columns)))
    df_new_Array.rename(columns={'id': 'Topic', 'variable': 'Sentence', 'value': 'Avg_Score'}, inplace=True)
    p = ggplot(aes(x='Sentence', y='Avg_Score', color='Topic'), data=df_new_Array)  + geom_point()  +  facet_wrap("Topic") +\
ggtitle("Plot: Occurrence of each topic - windowsize "+str(i)) 
    t = theme_gray()
    t._rcParams['font.size'] = 20 # Legend font size
    t._rcParams['xtick.labelsize'] = 20 # xaxis tick label size
    t._rcParams['ytick.labelsize'] = 20 # yaxis tick label size
    t._rcParams['axes.labelsize'] = 10  # axis label size
    t._rcParams['axes.titlesize'] = 40  # axis label size
    p + t
    p.save("Facet"+str(i)+".png" ,height=10,width=27)
    print("Saved ggplot")


    #Save hardmax plot
    df_new_max = dfmax
    df_new_max["id"] = df_new_max.index
    df_new_max = pd.melt(df_new_max, id_vars='id', value_vars=range(1,len(df_new_max.columns)))
    df_filter = df_new_max.loc[df_new_max['value'] != 0]

    plt.figure(figsize=(35,10))
    sns.set(font_scale = 2)
    ylabel = list(df_filter.groupby("id").sum().sort_values('value').index.values)
    df_filter.rename(columns={'id': 'Topic', 'variable': 'Sentence', 'value': 'Avg_Score'}, inplace=True)
    strip_plot = sns.stripplot(x='Sentence' , y = 'Topic', data=df_filter,order=ylabel,size = 10, color = 'green').set_title("Topics plot: windowsize "+str(i))
    fig = strip_plot.get_figure()
    plt.xlabel('Sentence')
    #plt.ylabel('Topics')

    fig.savefig('HardMax'+str(i)+'.png')

    #plt.show()
    print("Saved hardmaxplot")
# Out:
# 2
# i =  0
# 0 ['\ufeffNARRATOR: April 20th, 1918: In the skies over northern France, Allied and German fighter aircraft are locked in a ferocious dogfight.', 'One of the contenders in this aerial battle is the legendary German ace, Manfred von Richthofen: the Red Baron.']
#   Military aviation 1
#   Combat 1
#   Warfare 1
#   Military forces 1
#   Military 1
#   Aviation 1
#   War 1
#   Aerial warfare 1
#   Manfred von Richthofen 0.9629
#   Conflicts 0.9586
#   Military operations 0.9158
#   Aeronautics 0.902
#   Violent conflict 0.8368
#   International security 0.8312
#   Military science 0.8302
#   Military of Germany 0.8004
#   Wars 0.7943
#   Air forces 0.7911
#   Battles 0.756
#   Aerial operations and battles 0.7273
#   World War I 0.7234
#   National security 0.6723
#   Flying aces 0.6557
#   Flying ace 0.6503
#   Aircraft 0.648
#   Richthofen family 0.6369
#   Human rights abuses 0.6103
#   Warfare of the Industrial era 0.6097
#   Battles and operations of World War II 0.5913
#   Military aviators 0.5812
#   World War II 0.5773
#   Military air services 0.5649
#   World Wars 0.5588
#   Aces 0.5431
#   Global conflicts 0.5335
#   Disbanded air forces 0.5309
#   German World War I flying aces 0.5305
#   Aerospace engineering 0.5262
#   Western European theatre of World War II 0.5247
#   Aviators 0.5243
#   German military aviation 0.5165
#   Military aircraft 0.5107
#   Chronology of war 0.5088
# Phrase Number = 0
# ['Oswald Boelcke', 'Jagdstaffel', 'Jagdgeschwader 1 (World War I)', 'Dogfight', 'Bloody April', 'Synchronization gear', 'Aviation', 'World War I', 'Sopwith Camel', 'Fokker Dr.I', 'Max Immelmann', 'Anthony Fokker', 'Jagdstaffel 2', 'Cavalry', 'National security', 'Triplane', 'Aerial warfare', 'Jagdstaffel 11', 'Conflicts', 'Reconnaissance']
# Aviation 1
# Aerial warfare 1
# Conflicts 0.9586
# World War I 0.7234
# National security 0.6723
# val = 4.3543
# row = 0 sentence_num = 1
# Phrase Number = 1
# ['Air forces', 'Air force', 'Royal Air Force']
# Air forces 0.7911
# val = 0.7911
# row = 1 sentence_num = 1
# Phrase Number = 2
# ['No. 209 Squadron RAF']
# val = 0
# row = 2 sentence_num = 1
# Phrase Number = 3
# ['Manfred von Richthofen', 'Fighter aircraft', 'Luftstreitkräfte', 'Cedric Popkin', 'Flying ace', 'Military', 'Military science', 'Military forces', 'Warfare', 'Military aviation', 'War', 'Aeronautics', 'Trench warfare', 'Aircraft', 'International security', 'Sopwith Aviation Company', 'Lanoe Hawker', 'Airplane', 'Aerospace engineering', 'Combat', 'Royal Flying Corps', 'Military organization', 'Violent conflict', 'Military operations']
# Military aviation 1
# Combat 1
# Warfare 1
# Military forces 1
# Military 1
# War 1
# Manfred von Richthofen 0.9629
# Military operations 0.9158
# Aeronautics 0.902
# Violent conflict 0.8368
# International security 0.8312
# Military science 0.8302
# Flying ace 0.6503
# Aircraft 0.648
# Aerospace engineering 0.5262
# val = 13.103399999999999
# row = 3 sentence_num = 1
# Phrase Number = 4
# ['Imperial German Army Air Service']
# val = 0
# row = 4 sentence_num = 1
# Phrase Number = 5
# ['Roy Brown (RAF officer)']
# val = 0
# row = 5 sentence_num = 1
# i =  2
# 2 ['His distinctive red Fokker triplane is in hot pursuit over the Somme Valley; in its sights are two British Sopwith Camel fighters.', 'First one, and then the second are swiftly eliminated by the deadly marksman.']
#   Aircraft configurations 1
#   Military technology 1
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:179: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
#   Aerospace engineering 1
#   Military forces 1
#   Sopwith aircraft 1
#   Aeronautics 1
#   Vehicle design 1
#   Military aircraft of World War I 1
#   Multiplane aircraft 1
#   World War I 1
#   Aircraft wing design 1
#   Military equipment of World War I 1
#   Military aircraft 1
#   Wing configurations 1
#   Military aviation 1
#   Aircraft 1
#   Aviation 1
#   Tractor aircraft 0.9723
#   Single-engined tractor aircraft 0.9598
#   Military science 0.9385
#   Single-engine aircraft 0.9161
#   Aerospace 0.8915
#   Propeller aircraft 0.8595
#   Triplanes 0.8358
#   Military equipment 0.7318
#   Sopwith Aviation Company 0.7108
#   Triplane 0.6586
#   Fokker Dr.I 0.6048
#   Fokker 0.5565
#   Biplanes 0.5542
# Phrase Number = 0
# ['Oswald Boelcke', 'Jagdstaffel', 'Jagdgeschwader 1 (World War I)', 'Dogfight', 'Bloody April', 'Synchronization gear', 'Aviation', 'World War I', 'Sopwith Camel', 'Fokker Dr.I', 'Max Immelmann', 'Anthony Fokker', 'Jagdstaffel 2', 'Cavalry', 'National security', 'Triplane', 'Aerial warfare', 'Jagdstaffel 11', 'Conflicts', 'Reconnaissance']
# World War I 1
# Aviation 1
# Triplane 0.6586
# Fokker Dr.I 0.6048
# val = 3.2634
# row = 0 sentence_num = 2
# Phrase Number = 1
# ['Air forces', 'Air force', 'Royal Air Force']
# val = 0
# row = 1 sentence_num = 2
# Phrase Number = 2
# ['No. 209 Squadron RAF']
# val = 0
# row = 2 sentence_num = 2
# Phrase Number = 3
# ['Manfred von Richthofen', 'Fighter aircraft', 'Luftstreitkräfte', 'Cedric Popkin', 'Flying ace', 'Military', 'Military science', 'Military forces', 'Warfare', 'Military aviation', 'War', 'Aeronautics', 'Trench warfare', 'Aircraft', 'International security', 'Sopwith Aviation Company', 'Lanoe Hawker', 'Airplane', 'Aerospace engineering', 'Combat', 'Royal Flying Corps', 'Military organization', 'Violent conflict', 'Military operations']
# Aerospace engineering 1
# Military forces 1
# Aeronautics 1
# Military aviation 1
# Aircraft 1
# Military science 0.9385
# Sopwith Aviation Company 0.7108
# val = 6.6493
# row = 3 sentence_num = 2
# Phrase Number = 4
# ['Imperial German Army Air Service']
# val = 0
# row = 4 sentence_num = 2
# Phrase Number = 5
# ['Roy Brown (RAF officer)']
# val = 0
# row = 5 sentence_num = 2
# i =  4
# 4 ["They are the 79th and 80th kills of the Red Baron's career.", 'Below, the Germans are engaged in a final, massive offensive to end the First World War.']
#   Military of Germany 1
#   Wars 1
#   Military operations 0.9712
#   Military 0.9578
#   Warfare of the Industrial era 0.9572
#   War 0.9543
#   Warfare 0.8912
#   Foreign relations of Germany 0.8774
#   World War I 0.8515
#   2nd-millennium conflicts 0.8495
#   World Wars 0.8033
#   Global conflicts 0.7033
#   Conflicts 0.6922
#   Battles and operations of World War II 0.6192
#   European theatre of World War II 0.5645
#   International relations 0.5587
#   Battles 0.5351
#   World War II 0.5051
#   Eastern Front (World War II) 0.505
# Phrase Number = 0
# ['Oswald Boelcke', 'Jagdstaffel', 'Jagdgeschwader 1 (World War I)', 'Dogfight', 'Bloody April', 'Synchronization gear', 'Aviation', 'World War I', 'Sopwith Camel', 'Fokker Dr.I', 'Max Immelmann', 'Anthony Fokker', 'Jagdstaffel 2', 'Cavalry', 'National security', 'Triplane', 'Aerial warfare', 'Jagdstaffel 11', 'Conflicts', 'Reconnaissance']
# World War I 0.8515
# Conflicts 0.6922
# val = 1.5437
# row = 0 sentence_num = 3
# Phrase Number = 1
# ['Air forces', 'Air force', 'Royal Air Force']
# val = 0
# row = 1 sentence_num = 3
# Phrase Number = 2
# ['No. 209 Squadron RAF']
# val = 0
# row = 2 sentence_num = 3
# Phrase Number = 3
# ['Manfred von Richthofen', 'Fighter aircraft', 'Luftstreitkräfte', 'Cedric Popkin', 'Flying ace', 'Military', 'Military science', 'Military forces', 'Warfare', 'Military aviation', 'War', 'Aeronautics', 'Trench warfare', 'Aircraft', 'International security', 'Sopwith Aviation Company', 'Lanoe Hawker', 'Airplane', 'Aerospace engineering', 'Combat', 'Royal Flying Corps', 'Military organization', 'Violent conflict', 'Military operations']
# Military operations 0.9712
# Military 0.9578
# War 0.9543
# Warfare 0.8912
# val = 3.7744999999999997
# row = 3 sentence_num = 3
# Phrase Number = 4
# ['Imperial German Army Air Service']
# val = 0
# row = 4 sentence_num = 3
# Phrase Number = 5
# ['Roy Brown (RAF officer)']
# val = 0
# row = 5 sentence_num = 3
# i =  6
# 6 ['German troops and supplies pour into the Somme Valley in northeastern France.', 'To counter them, British and Australian soldiers set up defensive artillery and machine-gun positions on high ground overlooking the River Somme.']
#   Military of Germany 1
#   Campaigns and theatres of World War I 1
#   Conflicts 1
#   Western Front (World War I) 1
#   Military operations of the Industrial era 1
#   Military operations 1
#   Warfare of the Industrial era 1
#   International relations 1
#   Warfare 1
#   European theatre of World War I 1
#   Battle of the Somme 1
#   Global conflicts 1
#   Foreign relations of Germany 1
#   Military operations of World War I 1
#   War 1
#   2nd-millennium conflicts 1
#   Battles of World War I 1
#   Battles 1
#   Military 1
#   Wars 1
#   Battles of the Western Front (World War I) 1
#   Military of the United Kingdom 1
#   Battles of the European Theatre (World War I) 1
#   World Wars 1
#   World War I 1
#   Military of France 1
#   Somme 0.9782
#   Former republics 0.9421
#   Military of Australia 0.8763
#   Military science 0.7908
#   Departments of Nord-Pas-de-Calais-Picardie 0.7483
#   French Third Republic 0.7453
#   Battles and operations of World War II 0.7183
#   World War II 0.5807
#   Man-made disasters 0.5798
#   Departments of France 0.5423
# Phrase Number = 0
# ['Oswald Boelcke', 'Jagdstaffel', 'Jagdgeschwader 1 (World War I)', 'Dogfight', 'Bloody April', 'Synchronization gear', 'Aviation', 'World War I', 'Sopwith Camel', 'Fokker Dr.I', 'Max Immelmann', 'Anthony Fokker', 'Jagdstaffel 2', 'Cavalry', 'National security', 'Triplane', 'Aerial warfare', 'Jagdstaffel 11', 'Conflicts', 'Reconnaissance']
# Conflicts 1
# World War I 1
# val = 2
# row = 0 sentence_num = 4
# Phrase Number = 1
# ['Air forces', 'Air force', 'Royal Air Force']
# val = 0
# row = 1 sentence_num = 4
# Phrase Number = 2
# ['No. 209 Squadron RAF']
# val = 0
# row = 2 sentence_num = 4
# Phrase Number = 3
# ['Manfred von Richthofen', 'Fighter aircraft', 'Luftstreitkräfte', 'Cedric Popkin', 'Flying ace', 'Military', 'Military science', 'Military forces', 'Warfare', 'Military aviation', 'War', 'Aeronautics', 'Trench warfare', 'Aircraft', 'International security', 'Sopwith Aviation Company', 'Lanoe Hawker', 'Airplane', 'Aerospace engineering', 'Combat', 'Royal Flying Corps', 'Military organization', 'Violent conflict', 'Military operations']
# Military operations 1
# Warfare 1
# War 1
# Military 1
# Military science 0.7908
# val = 4.7908
# row = 3 sentence_num = 4
# Phrase Number = 4
# ['Imperial German Army Air Service']
# val = 0
# row = 4 sentence_num = 4
# Phrase Number = 5
# ['Roy Brown (RAF officer)']
# val = 0
# row = 5 sentence_num = 4
# i =  8
# 8 ['Part of their job is to watch out for German reconnaissance planes.', "Both armies need to know the position of each other's forces."]
#   Warfare 1
#   Military 0.9848
#   Military science 0.9035
#   Military forces 0.7632
#   War 0.7518
#   Military geography 0.7423
#   Military operations 0.6744
#   Reconnaissance 0.6503
#   Military intelligence collection 0.6182
#   Military strategy 0.6069
#   International security 0.6021
#   National security 0.5801
#   Military aviation 0.5675
#   Military intelligence 0.525
#   Warfare of the Industrial era 0.5136
# Phrase Number = 0
# ['Oswald Boelcke', 'Jagdstaffel', 'Jagdgeschwader 1 (World War I)', 'Dogfight', 'Bloody April', 'Synchronization gear', 'Aviation', 'World War I', 'Sopwith Camel', 'Fokker Dr.I', 'Max Immelmann', 'Anthony Fokker', 'Jagdstaffel 2', 'Cavalry', 'National security', 'Triplane', 'Aerial warfare', 'Jagdstaffel 11', 'Conflicts', 'Reconnaissance']
# Reconnaissance 0.6503
# National security 0.5801
# val = 1.2304
# row = 0 sentence_num = 5
# Phrase Number = 1
# ['Air forces', 'Air force', 'Royal Air Force']
# val = 0
# row = 1 sentence_num = 5
# Phrase Number = 2
# ['No. 209 Squadron RAF']
# val = 0
# row = 2 sentence_num = 5
# Phrase Number = 3
# ['Manfred von Richthofen', 'Fighter aircraft', 'Luftstreitkräfte', 'Cedric Popkin', 'Flying ace', 'Military', 'Military science', 'Military forces', 'Warfare', 'Military aviation', 'War', 'Aeronautics', 'Trench warfare', 'Aircraft', 'International security', 'Sopwith Aviation Company', 'Lanoe Hawker', 'Airplane', 'Aerospace engineering', 'Combat', 'Royal Flying Corps', 'Military organization', 'Violent conflict', 'Military operations']
# Warfare 1
# Military 0.9848
# Military science 0.9035
# Military forces 0.7632
# War 0.7518
# Military operations 0.6744
# International security 0.6021
# Military aviation 0.5675
# val = 6.2473
# row = 3 sentence_num = 5
# Phrase Number = 4
# ['Imperial German Army Air Service']
# val = 0
# row = 4 sentence_num = 5
# Phrase Number = 5
# ['Roy Brown (RAF officer)']
# val = 0
# row = 5 sentence_num = 5
# i =  10
# 10 ['This vital intelligence can only be gathered properly from the air.', 'Protecting German reconnaissance flights, Manfred von Richthofen, Germany\'s greatest ace, has brought his feared "flying circus" up to the front.']
#   Jagdgeschwader 1 (World War I) 1
#   Aviation 1
#   Military 1
#   Military aviation 1
#   Warfare 1
#   Aeronautics 1
#   War 1
#   Military science 1
#   Military operations 0.8686
#   Military forces 0.82
#   National security 0.8082
#   Conflicts 0.7946
#   Aircraft 0.7347
#   International security 0.7186
#   World War II 0.7143
#   Flying ace 0.6807
#   Air forces 0.6771
#   Global conflicts 0.6756
#   World War I 0.6548
#   Warfare of the Industrial era 0.6475
#   Military of Germany 0.631
#   World Wars 0.625
#   Manfred von Richthofen 0.6223
#   Wars 0.6206
#   Aerospace engineering 0.6024
#   Battles 0.6021
#   Aircraft configurations 0.5719
#   Combat 0.5495
#   International relations 0.5456
#   Battles and operations of World War II 0.5224
#   2nd-millennium conflicts 0.5122
# Phrase Number = 0
# ['Oswald Boelcke', 'Jagdstaffel', 'Jagdgeschwader 1 (World War I)', 'Dogfight', 'Bloody April', 'Synchronization gear', 'Aviation', 'World War I', 'Sopwith Camel', 'Fokker Dr.I', 'Max Immelmann', 'Anthony Fokker', 'Jagdstaffel 2', 'Cavalry', 'National security', 'Triplane', 'Aerial warfare', 'Jagdstaffel 11', 'Conflicts', 'Reconnaissance']
# Jagdgeschwader 1 (World War I) 1
# Aviation 1
# National security 0.8082
# Conflicts 0.7946
# World War I 0.6548
# val = 4.2576
# row = 0 sentence_num = 6
# Phrase Number = 1
# ['Air forces', 'Air force', 'Royal Air Force']
# Air forces 0.6771
# val = 0.6771
# row = 1 sentence_num = 6
# Phrase Number = 2
# ['No. 209 Squadron RAF']
# val = 0
# row = 2 sentence_num = 6
# Phrase Number = 3
# ['Manfred von Richthofen', 'Fighter aircraft', 'Luftstreitkräfte', 'Cedric Popkin', 'Flying ace', 'Military', 'Military science', 'Military forces', 'Warfare', 'Military aviation', 'War', 'Aeronautics', 'Trench warfare', 'Aircraft', 'International security', 'Sopwith Aviation Company', 'Lanoe Hawker', 'Airplane', 'Aerospace engineering', 'Combat', 'Royal Flying Corps', 'Military organization', 'Violent conflict', 'Military operations']
# Military 1
# Military aviation 1
# Warfare 1
# Aeronautics 1
# War 1
# Military science 1
# Military operations 0.8686
# Military forces 0.82
# Aircraft 0.7347
# International security 0.7186
# Flying ace 0.6807
# Manfred von Richthofen 0.6223
# Aerospace engineering 0.6024
# Combat 0.5495
# val = 11.596799999999998
# row = 3 sentence_num = 6
# Phrase Number = 4
# ['Imperial German Army Air Service']
# val = 0
# row = 4 sentence_num = 6
# Phrase Number = 5
# ['Roy Brown (RAF officer)']
# val = 0
# row = 5 sentence_num = 6
# i =  12
# 12 ['Opposing them are Royal Air Force squadrons flying the Sopwith Camel, one of the nimblest fighters ever built.', 'Both sides are flying airplanes vastly more advanced than the primitive machines at the outset of the First World War.']
#   Aircraft configurations 1
#   Warfare 1
#   Military aircraft 1
#   Aviation 1
#   Military aviation 1
#   Aircraft 1
#   Aeronautics 1
#   Military science 1
#   Military forces 1
#   Military 1
#   Aerospace engineering 0.9539
#   Sopwith Aviation Company 0.8905
#   Air forces 0.8748
#   Wing configurations 0.87
#   Sopwith Camel 0.8416
#   Tractor aircraft 0.7935
#   Air force 0.7836
#   Military air services 0.7712
#   Vehicle design 0.7564
#   Propeller aircraft 0.7533
#   Single-engine aircraft 0.7453
#   Fighter aircraft 0.7382
#   World War I 0.7343
#   Military technology 0.7213
#   War 0.6917
#   Aerial warfare 0.6766
#   Aircraft wing design 0.6751
#   Military units and formations 0.6571
#   Military equipment 0.6497
#   Aerospace 0.6141
#   Military equipment of World War I 0.6079
#   Single-engined tractor aircraft 0.5967
#   Monoplanes 0.5848
#   Royal Air Force 0.5774
#   Global conflicts 0.5752
#   International security 0.563
#   Military aircraft of World War I 0.5321
#   Squadron (aviation) 0.5069
#   Warfare of the Industrial era 0.5052
#   World Wars 0.5018
# Phrase Number = 0
# ['Oswald Boelcke', 'Jagdstaffel', 'Jagdgeschwader 1 (World War I)', 'Dogfight', 'Bloody April', 'Synchronization gear', 'Aviation', 'World War I', 'Sopwith Camel', 'Fokker Dr.I', 'Max Immelmann', 'Anthony Fokker', 'Jagdstaffel 2', 'Cavalry', 'National security', 'Triplane', 'Aerial warfare', 'Jagdstaffel 11', 'Conflicts', 'Reconnaissance']
# Aviation 1
# Sopwith Camel 0.8416
# World War I 0.7343
# Aerial warfare 0.6766
# val = 3.2525
# row = 0 sentence_num = 7
# Phrase Number = 1
# ['Air forces', 'Air force', 'Royal Air Force']
# Air forces 0.8748
# Air force 0.7836
# Royal Air Force 0.5774
# val = 2.2358
# row = 1 sentence_num = 7
# Phrase Number = 2
# ['No. 209 Squadron RAF']
# val = 0
# row = 2 sentence_num = 7
# Phrase Number = 3
# ['Manfred von Richthofen', 'Fighter aircraft', 'Luftstreitkräfte', 'Cedric Popkin', 'Flying ace', 'Military', 'Military science', 'Military forces', 'Warfare', 'Military aviation', 'War', 'Aeronautics', 'Trench warfare', 'Aircraft', 'International security', 'Sopwith Aviation Company', 'Lanoe Hawker', 'Airplane', 'Aerospace engineering', 'Combat', 'Royal Flying Corps', 'Military organization', 'Violent conflict', 'Military operations']
# Warfare 1
# Military aviation 1
# Aircraft 1
# Aeronautics 1
# Military science 1
# Military forces 1
# Military 1
# Aerospace engineering 0.9539
# Sopwith Aviation Company 0.8905
# Fighter aircraft 0.7382
# War 0.6917
# International security 0.563
# val = 10.8373
# row = 3 sentence_num = 7
# Phrase Number = 4
# ['Imperial German Army Air Service']
# val = 0
# row = 4 sentence_num = 7
# Phrase Number = 5
# ['Roy Brown (RAF officer)']
# val = 0
# row = 5 sentence_num = 7
# i =  14
# 14 ["Back then, in 1914, the fragile air forces of Europe's opposing nations were little more than a sideshow.", 'But after four years of rapid innovation, the first fighter airplanes were now efficient killing machines and their pilots, celebrated "knights of the air."']
#   Military science 1
#   Aviation 1
#   Aeronautics 1
#   Aircraft 1
#   Military aviation 1
#   Aerospace engineering 1
#   Aircraft configurations 1
#   Military aircraft 1
#   Warfare 1
#   Military 1
#   Military forces 1
#   Vehicle design 0.9877
#   Wing configurations 0.9498
#   Monoplanes 0.8936
#   Industries 0.8672
#   Tractor aircraft 0.8251
#   Propeller aircraft 0.7913
#   Single-engine aircraft 0.7833
#   Vehicles 0.7795
#   Aircraft wing design 0.7732
#   Aerial warfare 0.6865
#   Artificial objects 0.6586
#   War 0.6462
#   Fighter aircraft 0.62
#   Single-engined tractor aircraft 0.6161
#   Military technology 0.589
#   Low-wing aircraft 0.5786
#   Aircraft pilot 0.5581
#   Airplane 0.5384
#   World War II military aircraft 0.5024
# Phrase Number = 0
# ['Oswald Boelcke', 'Jagdstaffel', 'Jagdgeschwader 1 (World War I)', 'Dogfight', 'Bloody April', 'Synchronization gear', 'Aviation', 'World War I', 'Sopwith Camel', 'Fokker Dr.I', 'Max Immelmann', 'Anthony Fokker', 'Jagdstaffel 2', 'Cavalry', 'National security', 'Triplane', 'Aerial warfare', 'Jagdstaffel 11', 'Conflicts', 'Reconnaissance']
# Aviation 1
# Aerial warfare 0.6865
# val = 1.6865
# row = 0 sentence_num = 8
# Phrase Number = 1
# ['Air forces', 'Air force', 'Royal Air Force']
# val = 0
# row = 1 sentence_num = 8
# Phrase Number = 2
# ['No. 209 Squadron RAF']
# val = 0
# row = 2 sentence_num = 8
# Phrase Number = 3
# ['Manfred von Richthofen', 'Fighter aircraft', 'Luftstreitkräfte', 'Cedric Popkin', 'Flying ace', 'Military', 'Military science', 'Military forces', 'Warfare', 'Military aviation', 'War', 'Aeronautics', 'Trench warfare', 'Aircraft', 'International security', 'Sopwith Aviation Company', 'Lanoe Hawker', 'Airplane', 'Aerospace engineering', 'Combat', 'Royal Flying Corps', 'Military organization', 'Violent conflict', 'Military operations']
# Military science 1
# Aeronautics 1
# Aircraft 1
# Military aviation 1
# Aerospace engineering 1
# Warfare 1
# Military 1
# Military forces 1
# War 0.6462
# Fighter aircraft 0.62
# Airplane 0.5384
# val = 9.804599999999999
# row = 3 sentence_num = 8
# Phrase Number = 4
# ['Imperial German Army Air Service']
# val = 0
# row = 4 sentence_num = 8
# Phrase Number = 5
# ['Roy Brown (RAF officer)']
# val = 0
# row = 5 sentence_num = 8
# i =  16
# 16 ['The cost was horrific.', 'Thousands of airmen burned bright but died young.']
# Phrase Number = 0
# ['Oswald Boelcke', 'Jagdstaffel', 'Jagdgeschwader 1 (World War I)', 'Dogfight', 'Bloody April', 'Synchronization gear', 'Aviation', 'World War I', 'Sopwith Camel', 'Fokker Dr.I', 'Max Immelmann', 'Anthony Fokker', 'Jagdstaffel 2', 'Cavalry', 'National security', 'Triplane', 'Aerial warfare', 'Jagdstaffel 11', 'Conflicts', 'Reconnaissance']
# val = 0
# row = 0 sentence_num = 9
# Phrase Number = 1
# ['Air forces', 'Air force', 'Royal Air Force']
# val = 0
# row = 1 sentence_num = 9
# Phrase Number = 2
# ['No. 209 Squadron RAF']
# val = 0
# row = 2 sentence_num = 9
# Phrase Number = 3
# ['Manfred von Richthofen', 'Fighter aircraft', 'Luftstreitkräfte', 'Cedric Popkin', 'Flying ace', 'Military', 'Military science', 'Military forces', 'Warfare', 'Military aviation', 'War', 'Aeronautics', 'Trench warfare', 'Aircraft', 'International security', 'Sopwith Aviation Company', 'Lanoe Hawker', 'Airplane', 'Aerospace engineering', 'Combat', 'Royal Flying Corps', 'Military organization', 'Violent conflict', 'Military operations']
# val = 0
# row = 3 sentence_num = 9
# Phrase Number = 4
# ['Imperial German Army Air Service']
# val = 0
# row = 4 sentence_num = 9
# Phrase Number = 5
# ['Roy Brown (RAF officer)']
# val = 0
# row = 5 sentence_num = 9
# i =  18
# 18 ['The most famous and feared of all was Manfred von Richthofen.', 'Now, in April, 1918, with 80 kills to his name, von Richthofen is due to go home on leave.']
#   Manfred von Richthofen 1
#   Richthofen family 1
#   German World War I flying aces 1
#   German World War I pilots 0.9263
#   Luftstreitkräfte personnel 0.8963
#   Imperial German Army Air Service 0.7834
#   German flying aces 0.7304
#   World War I flying aces 0.6988
#   Recipients of the Order of Bravery, 4th class 0.6826
#   Recipients of the Silver Liakat Medal 0.619
#   Knights 1st Class of the Saxe-Ernestine House Order 0.5924
#   Recipients of the Order of the Red Eagle, 3rd class 0.5685
#   Recipients of the Silver Imtiyaz Medal 0.547
#   Flying aces 0.5289
#   World War I 0.528
#   World War I pilots 0.5156
# Phrase Number = 0
# ['Oswald Boelcke', 'Jagdstaffel', 'Jagdgeschwader 1 (World War I)', 'Dogfight', 'Bloody April', 'Synchronization gear', 'Aviation', 'World War I', 'Sopwith Camel', 'Fokker Dr.I', 'Max Immelmann', 'Anthony Fokker', 'Jagdstaffel 2', 'Cavalry', 'National security', 'Triplane', 'Aerial warfare', 'Jagdstaffel 11', 'Conflicts', 'Reconnaissance']
# World War I 0.528
# val = 0.528
# row = 0 sentence_num = 10
# Phrase Number = 1
# ['Air forces', 'Air force', 'Royal Air Force']
# val = 0
# row = 1 sentence_num = 10
# Phrase Number = 2
# ['No. 209 Squadron RAF']
# val = 0
# row = 2 sentence_num = 10
# Phrase Number = 3
# ['Manfred von Richthofen', 'Fighter aircraft', 'Luftstreitkräfte', 'Cedric Popkin', 'Flying ace', 'Military', 'Military science', 'Military forces', 'Warfare', 'Military aviation', 'War', 'Aeronautics', 'Trench warfare', 'Aircraft', 'International security', 'Sopwith Aviation Company', 'Lanoe Hawker', 'Airplane', 'Aerospace engineering', 'Combat', 'Royal Flying Corps', 'Military organization', 'Violent conflict', 'Military operations']
# Manfred von Richthofen 1
# val = 1
# row = 3 sentence_num = 10
# Phrase Number = 4
# ['Imperial German Army Air Service']
# Imperial German Army Air Service 0.7834
# val = 0.7834
# row = 4 sentence_num = 10
# Phrase Number = 5
# ['Roy Brown (RAF officer)']
# val = 0
# row = 5 sentence_num = 10
# i =  20
# 20 ['But his final day of active duty will end in death, clouded by mystery and controversy.', 'Only now has new evidence surfaced that may answer the question that has persisted for more than eighty years: Who Killed the Red Baron?']
#   Meteorology 0.6623
#   Clouds 0.5274
#   Meteorological phenomena 0.5197
# Phrase Number = 0
# ['Oswald Boelcke', 'Jagdstaffel', 'Jagdgeschwader 1 (World War I)', 'Dogfight', 'Bloody April', 'Synchronization gear', 'Aviation', 'World War I', 'Sopwith Camel', 'Fokker Dr.I', 'Max Immelmann', 'Anthony Fokker', 'Jagdstaffel 2', 'Cavalry', 'National security', 'Triplane', 'Aerial warfare', 'Jagdstaffel 11', 'Conflicts', 'Reconnaissance']
# val = 0
# row = 0 sentence_num = 11
# Phrase Number = 1
# ['Air forces', 'Air force', 'Royal Air Force']
# val = 0
# row = 1 sentence_num = 11
# Phrase Number = 2
# ['No. 209 Squadron RAF']
# val = 0
# row = 2 sentence_num = 11
# Phrase Number = 3
# ['Manfred von Richthofen', 'Fighter aircraft', 'Luftstreitkräfte', 'Cedric Popkin', 'Flying ace', 'Military', 'Military science', 'Military forces', 'Warfare', 'Military aviation', 'War', 'Aeronautics', 'Trench warfare', 'Aircraft', 'International security', 'Sopwith Aviation Company', 'Lanoe Hawker', 'Airplane', 'Aerospace engineering', 'Combat', 'Royal Flying Corps', 'Military organization', 'Violent conflict', 'Military operations']
# val = 0
# row = 3 sentence_num = 11
# Phrase Number = 4
# ['Imperial German Army Air Service']
# val = 0
# row = 4 sentence_num = 11
# Phrase Number = 5
# ['Roy Brown (RAF officer)']
# val = 0
# row = 5 sentence_num = 11
# i =  22
# 22 ['Up next on NOVA.', 'Major funding for NOVA is provided by the Park Foundation, dedicated to education and quality television.']
# Phrase Number = 0
# ['Oswald Boelcke', 'Jagdstaffel', 'Jagdgeschwader 1 (World War I)', 'Dogfight', 'Bloody April', 'Synchronization gear', 'Aviation', 'World War I', 'Sopwith Camel', 'Fokker Dr.I', 'Max Immelmann', 'Anthony Fokker', 'Jagdstaffel 2', 'Cavalry', 'National security', 'Triplane', 'Aerial warfare', 'Jagdstaffel 11', 'Conflicts', 'Reconnaissance']
# val = 0
# row = 0 sentence_num = 12
# Phrase Number = 1
# ['Air forces', 'Air force', 'Royal Air Force']
# val = 0
# row = 1 sentence_num = 12
# Phrase Number = 2
# ['No. 209 Squadron RAF']
# val = 0
# row = 2 sentence_num = 12
# Phrase Number = 3
# ['Manfred von Richthofen', 'Fighter aircraft', 'Luftstreitkräfte', 'Cedric Popkin', 'Flying ace', 'Military', 'Military science', 'Military forces', 'Warfare', 'Military aviation', 'War', 'Aeronautics', 'Trench warfare', 'Aircraft', 'International security', 'Sopwith Aviation Company', 'Lanoe Hawker', 'Airplane', 'Aerospace engineering', 'Combat', 'Royal Flying Corps', 'Military organization', 'Violent conflict', 'Military operations']
# val = 0
# row = 3 sentence_num = 12
# Phrase Number = 4
# ['Imperial German Army Air Service']
# val = 0
# row = 4 sentence_num = 12
# Phrase Number = 5
# ['Roy Brown (RAF officer)']
# val = 0
# row = 5 sentence_num = 12
# i =  24
# 24 ['We see 400 employees in three years.', 'At Microsoft, your potential inspires us to create software that helps you reach it.']
#   Software 1
#   Computing 1
#   Microsoft 1
#   Digital media 1
#   Information technology companies of the United States 1
#   Technology 0.8927
#   Information technology companies 0.8737
#   Digital technology 0.8309
#   Cyberspace 0.7622
#   Computers 0.6992
#   Intellectual works 0.6895
#   Computer engineering 0.6855
#   Business 0.6643
#   Media technology 0.6574
#   Technology companies of the United States 0.6202
#   Computer science 0.6173
#   Computer-related introductions 0.6045
#   Information technology 0.5971
#   Communication 0.5622
#   Software companies of the United States 0.5549
#   Foreign trade of the United States 0.5449
#   Computer companies 0.5394
#   Application software 0.5224
#   Electronic publishing 0.5046
# Phrase Number = 0
# ['Oswald Boelcke', 'Jagdstaffel', 'Jagdgeschwader 1 (World War I)', 'Dogfight', 'Bloody April', 'Synchronization gear', 'Aviation', 'World War I', 'Sopwith Camel', 'Fokker Dr.I', 'Max Immelmann', 'Anthony Fokker', 'Jagdstaffel 2', 'Cavalry', 'National security', 'Triplane', 'Aerial warfare', 'Jagdstaffel 11', 'Conflicts', 'Reconnaissance']
# val = 0
# row = 0 sentence_num = 13
# Phrase Number = 1
# ['Air forces', 'Air force', 'Royal Air Force']
# val = 0
# row = 1 sentence_num = 13
# Phrase Number = 2
# ['No. 209 Squadron RAF']
# val = 0
# row = 2 sentence_num = 13
# Phrase Number = 3
# ['Manfred von Richthofen', 'Fighter aircraft', 'Luftstreitkräfte', 'Cedric Popkin', 'Flying ace', 'Military', 'Military science', 'Military forces', 'Warfare', 'Military aviation', 'War', 'Aeronautics', 'Trench warfare', 'Aircraft', 'International security', 'Sopwith Aviation Company', 'Lanoe Hawker', 'Airplane', 'Aerospace engineering', 'Combat', 'Royal Flying Corps', 'Military organization', 'Violent conflict', 'Military operations']
# val = 0
# row = 3 sentence_num = 13
# Phrase Number = 4
# ['Imperial German Army Air Service']
# val = 0
# row = 4 sentence_num = 13
# Phrase Number = 5
# ['Roy Brown (RAF officer)']
# val = 0
# row = 5 sentence_num = 13
# i =  26
# 26 ['Your potential, our passion.', "Science: it's given us the framework to help make wireless communications clear."]
#   Communication 0.8514
#   Technology 0.8302
#   Telecommunications 0.7783
#   Wireless 0.6611
#   Electronics 0.5707
#   Computing 0.5427
# Phrase Number = 0
# ['Oswald Boelcke', 'Jagdstaffel', 'Jagdgeschwader 1 (World War I)', 'Dogfight', 'Bloody April', 'Synchronization gear', 'Aviation', 'World War I', 'Sopwith Camel', 'Fokker Dr.I', 'Max Immelmann', 'Anthony Fokker', 'Jagdstaffel 2', 'Cavalry', 'National security', 'Triplane', 'Aerial warfare', 'Jagdstaffel 11', 'Conflicts', 'Reconnaissance']
# val = 0
# row = 0 sentence_num = 14
# Phrase Number = 1
# ['Air forces', 'Air force', 'Royal Air Force']
# val = 0
# row = 1 sentence_num = 14
# Phrase Number = 2
# ['No. 209 Squadron RAF']
# val = 0
# row = 2 sentence_num = 14
# Phrase Number = 3
# ['Manfred von Richthofen', 'Fighter aircraft', 'Luftstreitkräfte', 'Cedric Popkin', 'Flying ace', 'Military', 'Military science', 'Military forces', 'Warfare', 'Military aviation', 'War', 'Aeronautics', 'Trench warfare', 'Aircraft', 'International security', 'Sopwith Aviation Company', 'Lanoe Hawker', 'Airplane', 'Aerospace engineering', 'Combat', 'Royal Flying Corps', 'Military organization', 'Violent conflict', 'Military operations']
# val = 0
# row = 3 sentence_num = 14
# Phrase Number = 4
# ['Imperial German Army Air Service']
# val = 0
# row = 4 sentence_num = 14
# Phrase Number = 5
# ['Roy Brown (RAF officer)']
# val = 0
# row = 5 sentence_num = 14
# i =  28
# 28 ['Sprint is proud to support NOVA.', 'And by the Corporation for Public Broadcasting, and by contributions to your PBS station from viewers like you.']
#   Broadcasting 1
#   Television 1
#   Public broadcasting 1
#   Mass media 1
#   Public Broadcasting Service 1
#   Educational television 1
#   Public television 1
#   Corporation for Public Broadcasting 1
#   Public sphere 1
#   Public sector 1
#   Public services 1
#   Media formats 1
#   Government 0.9556
#   Television networks 0.9225
#   Broadcasting stations and networks 0.8992
#   Educational broadcasting 0.8863
#   American television networks 0.8641
#   Television broadcasting companies 0.8144
#   Broadcasting companies of the United States 0.8113
#   Public administration 0.8099
#   Communication 0.7964
#   Television companies 0.739
#   Government corporations 0.6715
#   Technology 0.6553
#   Telecommunications 0.6375
#   Economy of the United States 0.6221
#   Government of the United States 0.6168
#   Media companies of the United States 0.6127
#   Radio 0.563
#   United States 0.5592
#   Media companies of North America 0.5368
#   Corporations chartered 0.53
#   Media technology 0.5041
# Phrase Number = 0
# ['Oswald Boelcke', 'Jagdstaffel', 'Jagdgeschwader 1 (World War I)', 'Dogfight', 'Bloody April', 'Synchronization gear', 'Aviation', 'World War I', 'Sopwith Camel', 'Fokker Dr.I', 'Max Immelmann', 'Anthony Fokker', 'Jagdstaffel 2', 'Cavalry', 'National security', 'Triplane', 'Aerial warfare', 'Jagdstaffel 11', 'Conflicts', 'Reconnaissance']
# val = 0
# row = 0 sentence_num = 15
# Phrase Number = 1
# ['Air forces', 'Air force', 'Royal Air Force']
# val = 0
# row = 1 sentence_num = 15
# Phrase Number = 2
# ['No. 209 Squadron RAF']
# val = 0
# row = 2 sentence_num = 15
# Phrase Number = 3
# ['Manfred von Richthofen', 'Fighter aircraft', 'Luftstreitkräfte', 'Cedric Popkin', 'Flying ace', 'Military', 'Military science', 'Military forces', 'Warfare', 'Military aviation', 'War', 'Aeronautics', 'Trench warfare', 'Aircraft', 'International security', 'Sopwith Aviation Company', 'Lanoe Hawker', 'Airplane', 'Aerospace engineering', 'Combat', 'Royal Flying Corps', 'Military organization', 'Violent conflict', 'Military operations']
# val = 0
# row = 3 sentence_num = 15
# Phrase Number = 4
# ['Imperial German Army Air Service']
# val = 0
# row = 4 sentence_num = 15
# Phrase Number = 5
# ['Roy Brown (RAF officer)']
# val = 0
# row = 5 sentence_num = 15
# i =  30
# 30 ['Thank you.', 'NARRATOR: In 1917, the U.S. entered World War I, and the first American troops landed in France.']
#   World Wars 0.7335
#   World War I 0.6942
#   Wars 0.6599
#   Russia–Turkey military relations 0.6297
#   Global conflicts 0.6027
#   Russo-Turkish Wars 0.5785
#   Violent conflict 0.5566
#   War 0.5367
#   Foreign relations of Germany 0.5184
# Phrase Number = 0
# ['Oswald Boelcke', 'Jagdstaffel', 'Jagdgeschwader 1 (World War I)', 'Dogfight', 'Bloody April', 'Synchronization gear', 'Aviation', 'World War I', 'Sopwith Camel', 'Fokker Dr.I', 'Max Immelmann', 'Anthony Fokker', 'Jagdstaffel 2', 'Cavalry', 'National security', 'Triplane', 'Aerial warfare', 'Jagdstaffel 11', 'Conflicts', 'Reconnaissance']
# World War I 0.6942
# val = 0.6942
# row = 0 sentence_num = 16
# Phrase Number = 1
# ['Air forces', 'Air force', 'Royal Air Force']
# val = 0
# row = 1 sentence_num = 16
# Phrase Number = 2
# ['No. 209 Squadron RAF']
# val = 0
# row = 2 sentence_num = 16
# Phrase Number = 3
# ['Manfred von Richthofen', 'Fighter aircraft', 'Luftstreitkräfte', 'Cedric Popkin', 'Flying ace', 'Military', 'Military science', 'Military forces', 'Warfare', 'Military aviation', 'War', 'Aeronautics', 'Trench warfare', 'Aircraft', 'International security', 'Sopwith Aviation Company', 'Lanoe Hawker', 'Airplane', 'Aerospace engineering', 'Combat', 'Royal Flying Corps', 'Military organization', 'Violent conflict', 'Military operations']
# Violent conflict 0.5566
# War 0.5367
# val = 1.0933
# row = 3 sentence_num = 16
# Phrase Number = 4
# ['Imperial German Army Air Service']
# val = 0
# row = 4 sentence_num = 16
# Phrase Number = 5
# ['Roy Brown (RAF officer)']
# val = 0
# row = 5 sentence_num = 16
# i =  32
# 32 ['Eventually, American arms would turn the tide against Germany, but in the spring of 1918, the Germans launch one final offensive to break the stalemate of the trench war.', 'On the morning of April 21st, Manfred von Richthofen, the Red Baron, takes off with a formation of Fokker Dr 1 fighters.']
#   Foreign relations of Germany 1
#   Warfare of the Industrial era 1
#   World War I 1
#   Battles 1
#   Warfare 1
#   Military operations 1
#   2nd-millennium conflicts 1
#   Conflicts 1
#   War 1
#   Wars 1
#   Military 1
#   Military of Germany 1
#   Manfred von Richthofen 0.9752
#   Aviation 0.9176
#   Military operations of World War I 0.9103
#   World Wars 0.8982
#   Military aviation 0.8705
#   Military operations of the Industrial era 0.8551
#   Battles of World War I 0.8541
#   Military science 0.8537
#   Campaigns and theatres of World War I 0.8416
#   Global conflicts 0.8329
#   Western Front (World War I) 0.8254
#   Battles of the European Theatre (World War I) 0.8175
#   Battles of the Western Front (World War I) 0.7791
#   European theatre of World War I 0.768
#   Military of the United Kingdom 0.7472
#   Combat 0.7003
#   International relations 0.6766
#   Battles and operations of World War II 0.636
#   World War II 0.6283
#   Richthofen family 0.6204
#   German World War I flying aces 0.5697
#   Western European theatre of World War II 0.5424
#   Military of France 0.53
#   Military equipment of World War I 0.5274
#   German World War I pilots 0.5238
#   Imperial German Army Air Service 0.5195
#   Fokker Dr.I 0.5176
#   European theatre of World War II 0.5143
#   International security 0.5084
#   Luftstreitkräfte personnel 0.5061
# Phrase Number = 0
# ['Oswald Boelcke', 'Jagdstaffel', 'Jagdgeschwader 1 (World War I)', 'Dogfight', 'Bloody April', 'Synchronization gear', 'Aviation', 'World War I', 'Sopwith Camel', 'Fokker Dr.I', 'Max Immelmann', 'Anthony Fokker', 'Jagdstaffel 2', 'Cavalry', 'National security', 'Triplane', 'Aerial warfare', 'Jagdstaffel 11', 'Conflicts', 'Reconnaissance']
# World War I 1
# Conflicts 1
# Aviation 0.9176
# Fokker Dr.I 0.5176
# val = 3.4352
# row = 0 sentence_num = 17
# Phrase Number = 1
# ['Air forces', 'Air force', 'Royal Air Force']
# val = 0
# row = 1 sentence_num = 17
# Phrase Number = 2
# ['No. 209 Squadron RAF']
# val = 0
# row = 2 sentence_num = 17
# Phrase Number = 3
# ['Manfred von Richthofen', 'Fighter aircraft', 'Luftstreitkräfte', 'Cedric Popkin', 'Flying ace', 'Military', 'Military science', 'Military forces', 'Warfare', 'Military aviation', 'War', 'Aeronautics', 'Trench warfare', 'Aircraft', 'International security', 'Sopwith Aviation Company', 'Lanoe Hawker', 'Airplane', 'Aerospace engineering', 'Combat', 'Royal Flying Corps', 'Military organization', 'Violent conflict', 'Military operations']
# Warfare 1
# Military operations 1
# War 1
# Military 1
# Manfred von Richthofen 0.9752
# Military aviation 0.8705
# Military science 0.8537
# Combat 0.7003
# International security 0.5084
# val = 7.9081
# row = 3 sentence_num = 17
# Phrase Number = 4
# ['Imperial German Army Air Service']
# Imperial German Army Air Service 0.5195
# val = 0.5195
# row = 4 sentence_num = 17
# Phrase Number = 5
# ['Roy Brown (RAF officer)']
# val = 0
# row = 5 sentence_num = 17
# i =  34
# 34 ['Meanwhile, a British Royal Air Force patrol of Sopwith Camel fighters is climbing high over the front lines.', 'A dogfight begins and Allied troops in the trenches below see a Sopwith Camel break away, chased by a distinctive red Fokker triplane.']
#   Sopwith Aviation Company 1
#   Sopwith Camel 1
#   Aircraft 1
#   Military forces 1
#   Military aircraft 1
#   World War I 1
#   Military science 1
#   Warfare 1
#   Military aviation 1
#   Aviation 1
#   Military 0.9749
#   Aeronautics 0.946
#   Wing configurations 0.9369
#   Aircraft configurations 0.9356
#   War 0.8818
#   Triplane 0.8733
#   Military equipment of World War I 0.8369
#   Warfare of the Industrial era 0.8308
#   Military operations 0.8066
#   Aircraft wing design 0.7961
#   Aerospace engineering 0.7833
#   Battles 0.7229
#   Military aircraft of World War I 0.7207
#   Vehicle design 0.7199
#   Wars 0.7174
#   Fokker Dr.I 0.7089
#   Conflicts 0.7055
#   Global conflicts 0.7009
#   Aerial warfare 0.6824
#   Fighter aircraft 0.6822
#   Dogfight 0.6814
#   Military technology 0.6792
#   Military of the United Kingdom 0.6564
#   World Wars 0.6495
#   Tractor aircraft 0.6303
#   Single-engine aircraft 0.6067
#   Multiplane aircraft 0.6054
#   Single-engined tractor aircraft 0.5955
#   Military equipment 0.56
#   Propeller aircraft 0.5594
#   2nd-millennium conflicts 0.5586
#   Aerospace 0.518
# Phrase Number = 0
# ['Oswald Boelcke', 'Jagdstaffel', 'Jagdgeschwader 1 (World War I)', 'Dogfight', 'Bloody April', 'Synchronization gear', 'Aviation', 'World War I', 'Sopwith Camel', 'Fokker Dr.I', 'Max Immelmann', 'Anthony Fokker', 'Jagdstaffel 2', 'Cavalry', 'National security', 'Triplane', 'Aerial warfare', 'Jagdstaffel 11', 'Conflicts', 'Reconnaissance']
# Sopwith Camel 1
# World War I 1
# Aviation 1
# Triplane 0.8733
# Fokker Dr.I 0.7089
# Conflicts 0.7055
# Aerial warfare 0.6824
# Dogfight 0.6814
# val = 6.6515
# row = 0 sentence_num = 18
# Phrase Number = 1
# ['Air forces', 'Air force', 'Royal Air Force']
# val = 0
# row = 1 sentence_num = 18
# Phrase Number = 2
# ['No. 209 Squadron RAF']
# val = 0
# row = 2 sentence_num = 18
# Phrase Number = 3
# ['Manfred von Richthofen', 'Fighter aircraft', 'Luftstreitkräfte', 'Cedric Popkin', 'Flying ace', 'Military', 'Military science', 'Military forces', 'Warfare', 'Military aviation', 'War', 'Aeronautics', 'Trench warfare', 'Aircraft', 'International security', 'Sopwith Aviation Company', 'Lanoe Hawker', 'Airplane', 'Aerospace engineering', 'Combat', 'Royal Flying Corps', 'Military organization', 'Violent conflict', 'Military operations']
# Sopwith Aviation Company 1
# Aircraft 1
# Military forces 1
# Military science 1
# Warfare 1
# Military aviation 1
# Military 0.9749
# Aeronautics 0.946
# War 0.8818
# Military operations 0.8066
# Aerospace engineering 0.7833
# Fighter aircraft 0.6822
# val = 11.0748
# row = 3 sentence_num = 18
# Phrase Number = 4
# ['Imperial German Army Air Service']
# val = 0
# row = 4 sentence_num = 18
# Phrase Number = 5
# ['Roy Brown (RAF officer)']
# val = 0
# row = 5 sentence_num = 18
# i =  36
# 36 ['The Red Baron pursues his quarry, piloted by Lieutenant Wilfrid May, deep into Allied territory.', 'But as the Baron prepares to strike, a second Camel piloted by Captain Roy Brown dives steeply to intercept him.']
#   Roy Brown (RAF officer) 1
#   Military aviation 1
#   Aviation 1
#   Military 1
#   Manfred von Richthofen 1
#   Warfare 1
#   Richthofen family 1
#   German World War I flying aces 0.8925
#   Aerial warfare 0.8594
#   German World War I pilots 0.8363
#   Military operations 0.8188
#   Battles 0.7771
#   Luftstreitkräfte personnel 0.7364
#   War 0.7345
#   Warfare of the Industrial era 0.714
#   Military science 0.6949
#   Aerial operations and battles 0.6824
#   World War I flying aces 0.6616
#   Conflicts 0.6196
#   Battles and operations of World War II 0.6169
#   Air forces 0.6037
#   World War I 0.5895
#   Theaters and campaigns of World War II 0.5836
#   Imperial German Army Air Service 0.5809
#   Wars 0.5731
#   German flying aces 0.5631
#   2nd-millennium conflicts 0.5482
#   Combat 0.5461
#   Military of the United Kingdom 0.5437
#   Global conflicts 0.5339
#   Naval aviation 0.5283
#   World War II 0.52
#   Military aviators 0.518
#   Pacific theatre of World War II 0.5104
#   Military forces 0.5103
#   World War I pilots 0.505
#   Naval warfare 0.5017
# Phrase Number = 0
# ['Oswald Boelcke', 'Jagdstaffel', 'Jagdgeschwader 1 (World War I)', 'Dogfight', 'Bloody April', 'Synchronization gear', 'Aviation', 'World War I', 'Sopwith Camel', 'Fokker Dr.I', 'Max Immelmann', 'Anthony Fokker', 'Jagdstaffel 2', 'Cavalry', 'National security', 'Triplane', 'Aerial warfare', 'Jagdstaffel 11', 'Conflicts', 'Reconnaissance']
# Aviation 1
# Aerial warfare 0.8594
# Conflicts 0.6196
# World War I 0.5895
# val = 3.0685000000000002
# row = 0 sentence_num = 19
# Phrase Number = 1
# ['Air forces', 'Air force', 'Royal Air Force']
# Air forces 0.6037
# val = 0.6037
# row = 1 sentence_num = 19
# Phrase Number = 2
# ['No. 209 Squadron RAF']
# val = 0
# row = 2 sentence_num = 19
# Phrase Number = 3
# ['Manfred von Richthofen', 'Fighter aircraft', 'Luftstreitkräfte', 'Cedric Popkin', 'Flying ace', 'Military', 'Military science', 'Military forces', 'Warfare', 'Military aviation', 'War', 'Aeronautics', 'Trench warfare', 'Aircraft', 'International security', 'Sopwith Aviation Company', 'Lanoe Hawker', 'Airplane', 'Aerospace engineering', 'Combat', 'Royal Flying Corps', 'Military organization', 'Violent conflict', 'Military operations']
# Military aviation 1
# Military 1
# Manfred von Richthofen 1
# Warfare 1
# Military operations 0.8188
# War 0.7345
# Military science 0.6949
# Combat 0.5461
# Military forces 0.5103
# val = 7.304599999999999
# row = 3 sentence_num = 19
# Phrase Number = 4
# ['Imperial German Army Air Service']
# Imperial German Army Air Service 0.5809
# val = 0.5809
# row = 4 sentence_num = 19
# Phrase Number = 5
# ['Roy Brown (RAF officer)']
# Roy Brown (RAF officer) 1
# val = 1
# row = 5 sentence_num = 19
# i =  38
# 38 ['Bursts of machine gun fire from ground and air erupt across the Somme Valley.', 'But instead of Lieutenant May spinning to his death, it is the red triplane that has plummeted from the sky.']
#   Machine guns 0.7073
#   Automatic weapons 0.6577
#   Weapons 0.6495
#   Firearm actions 0.618
#   Firearms 0.5977
#   Projectile weapons 0.588
#   Weapon design 0.5828
#   Firearm components 0.5587
#   Projectiles 0.5555
#   Technology 0.5276
#   Machines 0.5018
# Phrase Number = 0
# ['Oswald Boelcke', 'Jagdstaffel', 'Jagdgeschwader 1 (World War I)', 'Dogfight', 'Bloody April', 'Synchronization gear', 'Aviation', 'World War I', 'Sopwith Camel', 'Fokker Dr.I', 'Max Immelmann', 'Anthony Fokker', 'Jagdstaffel 2', 'Cavalry', 'National security', 'Triplane', 'Aerial warfare', 'Jagdstaffel 11', 'Conflicts', 'Reconnaissance']
# val = 0
# row = 0 sentence_num = 20
# Phrase Number = 1
# ['Air forces', 'Air force', 'Royal Air Force']
# val = 0
# row = 1 sentence_num = 20
# Phrase Number = 2
# ['No. 209 Squadron RAF']
# val = 0
# row = 2 sentence_num = 20
# Phrase Number = 3
# ['Manfred von Richthofen', 'Fighter aircraft', 'Luftstreitkräfte', 'Cedric Popkin', 'Flying ace', 'Military', 'Military science', 'Military forces', 'Warfare', 'Military aviation', 'War', 'Aeronautics', 'Trench warfare', 'Aircraft', 'International security', 'Sopwith Aviation Company', 'Lanoe Hawker', 'Airplane', 'Aerospace engineering', 'Combat', 'Royal Flying Corps', 'Military organization', 'Violent conflict', 'Military operations']
# val = 0
# row = 3 sentence_num = 20
# Phrase Number = 4
# ['Imperial German Army Air Service']
# val = 0
# row = 4 sentence_num = 20
# Phrase Number = 5
# ['Roy Brown (RAF officer)']
# val = 0
# row = 5 sentence_num = 20
# i =  40
# 40 ['Ten days before his 26th birthday, Manfred von Richthofen is dead.', 'The great pilot and tactician had broken one of his own key rules, pursuing a risky low-level chase into enemy territory.']
#   Manfred von Richthofen 1
#   Richthofen family 1
#   German World War I flying aces 0.8662
#   Military aviation 0.8155
#   German World War I pilots 0.7861
#   Luftstreitkräfte personnel 0.7602
#   Aviation 0.7546
#   Imperial German Army Air Service 0.743
#   Military 0.6907
#   German flying aces 0.6171
#   World War I 0.6035
#   World War I flying aces 0.5902
#   Recipients of the Order of Bravery, 4th class 0.5846
#   Flying aces 0.5402
#   Recipients of the Silver Liakat Medal 0.5289
#   Knights 1st Class of the Saxe-Ernestine House Order 0.5056
# Phrase Number = 0
# ['Oswald Boelcke', 'Jagdstaffel', 'Jagdgeschwader 1 (World War I)', 'Dogfight', 'Bloody April', 'Synchronization gear', 'Aviation', 'World War I', 'Sopwith Camel', 'Fokker Dr.I', 'Max Immelmann', 'Anthony Fokker', 'Jagdstaffel 2', 'Cavalry', 'National security', 'Triplane', 'Aerial warfare', 'Jagdstaffel 11', 'Conflicts', 'Reconnaissance']
# Aviation 0.7546
# World War I 0.6035
# val = 1.3581
# row = 0 sentence_num = 21
# Phrase Number = 1
# ['Air forces', 'Air force', 'Royal Air Force']
# val = 0
# row = 1 sentence_num = 21
# Phrase Number = 2
# ['No. 209 Squadron RAF']
# val = 0
# row = 2 sentence_num = 21
# Phrase Number = 3
# ['Manfred von Richthofen', 'Fighter aircraft', 'Luftstreitkräfte', 'Cedric Popkin', 'Flying ace', 'Military', 'Military science', 'Military forces', 'Warfare', 'Military aviation', 'War', 'Aeronautics', 'Trench warfare', 'Aircraft', 'International security', 'Sopwith Aviation Company', 'Lanoe Hawker', 'Airplane', 'Aerospace engineering', 'Combat', 'Royal Flying Corps', 'Military organization', 'Violent conflict', 'Military operations']
# Manfred von Richthofen 1
# Military aviation 0.8155
# Military 0.6907
# val = 2.5062
# row = 3 sentence_num = 21
# Phrase Number = 4
# ['Imperial German Army Air Service']
# Imperial German Army Air Service 0.743
# val = 0.743
# row = 4 sentence_num = 21
# Phrase Number = 5
# ['Roy Brown (RAF officer)']
# val = 0
# row = 5 sentence_num = 21
# i =  42
# 42 ['BARON HERMANN VON RICHTHOFEN (Great Nephew of Manfred von Richtofen): Manfred, of course, was a human being, and a human being is not without faults.', 'And he had been very serious about the question of life and death, and he must have known that one day he would be a victim himself.']
#   Manfred von Richthofen 1
#   Recipients of the Silver Liakat Medal 1
#   World War I flying aces 1
#   Recipients of the Silver Imtiyaz Medal 1
#   German flying aces 1
#   Recipients of the Order of the Red Eagle, 3rd class 1
#   Imperial German Army Air Service 1
#   Knights 1st Class of the Saxe-Ernestine House Order 1
#   Luftstreitkräfte personnel 1
#   Recipients of the Order of Bravery, 4th class 1
#   Barons of Germany 1
#   German World War I pilots 1
#   German World War I flying aces 1
#   Richthofen family 1
#   German noble titles 0.9771
#   German casualties of World War I 0.9449
#   Aviators killed 0.9195
#   Victims of aircraft shootdowns 0.8958
#   Recipients of the Hanseatic Cross (Lübeck) 0.8736
#   German nobility 0.8645
#   German people 0.8304
#   Shot-down aviators 0.8294
#   World War I pilots 0.7772
#   World War I 0.7663
#   Recipients of the Hanseatic Cross (Bremen) 0.7659
#   Recipients of the Pour le Mérite (military class) 0.7575
#   Flying aces 0.7518
# ...
#   Knights 1st Class of the Saxe-Ernestine House Order 0.82
#   Recipients of the Order of the Red Eagle, 3rd class 0.7885
#   Recipients of the Silver Imtiyaz Medal 0.7599
#   German casualties of World War I 0.668
#   Aviators killed 0.6492
#   Victims of aircraft shootdowns 0.6317
#   Recipients of the Hanseatic Cross (Lübeck) 0.6154
#   Barons of Germany 0.5857
#   Shot-down aviators 0.5473
#   Recipients of the Hanseatic Cross (Bremen) 0.5359
#   Military 0.5275
#   Recipients of the Imtiyaz Medal 0.525
#   Recipients of the Liakat Medal 0.5146
#   Knights of the House Order of Hohenzollern 0.5048
# Phrase Number = 0
# ['Oswald Boelcke', 'Jagdstaffel', 'Jagdgeschwader 1 (World War I)', 'Dogfight', 'Bloody April', 'Synchronization gear', 'Aviation', 'World War I', 'Sopwith Camel', 'Fokker Dr.I', 'Max Immelmann', 'Anthony Fokker', 'Jagdstaffel 2', 'Cavalry', 'National security', 'Triplane', 'Aerial warfare', 'Jagdstaffel 11', 'Conflicts', 'Reconnaissance']
# val = 0
# row = 0 sentence_num = 198
# Phrase Number = 1
# ['Air forces', 'Air force', 'Royal Air Force']
# val = 0
# row = 1 sentence_num = 198
# Phrase Number = 2
# ['No. 209 Squadron RAF']
# val = 0
# row = 2 sentence_num = 198
# Phrase Number = 3
# ['Manfred von Richthofen', 'Fighter aircraft', 'Luftstreitkräfte', 'Cedric Popkin', 'Flying ace', 'Military', 'Military science', 'Military forces', 'Warfare', 'Military aviation', 'War', 'Aeronautics', 'Trench warfare', 'Aircraft', 'International security', 'Sopwith Aviation Company', 'Lanoe Hawker', 'Airplane', 'Aerospace engineering', 'Combat', 'Royal Flying Corps', 'Military organization', 'Violent conflict', 'Military operations']
# Cedric Popkin 1
# Manfred von Richthofen 1
# Military 0.5275
# val = 2.5275
# row = 3 sentence_num = 198
# Phrase Number = 4
# ['Imperial German Army Air Service']
# Imperial German Army Air Service 1
# val = 1
# row = 4 sentence_num = 198
# Phrase Number = 5
# ['Roy Brown (RAF officer)']
# val = 0
# row = 5 sentence_num = 198
# i =  398
# 398 ['NARRATOR: Though he was their greatest foe, the Allies buried Manfred von Richthofen alongside their own dead on April 22, 1918, with full military honors.', 'BARON HERMANN VON RICHTHOFEN: It is very sad and ironic that he was killed at the height of his competence and success.']
#   Richthofen family 1
#   Manfred von Richthofen 1
#   German World War I flying aces 0.797
#   German World War I pilots 0.7177
#   Luftstreitkräfte personnel 0.6937
#   Barons of Germany 0.6364
#   Imperial German Army Air Service 0.6013
#   German flying aces 0.5581
#   World War I 0.535
#   World War I flying aces 0.5344
#   Military 0.5105
#   Recipients of the Order of Bravery, 4th class 0.5085
# Phrase Number = 0
# ['Oswald Boelcke', 'Jagdstaffel', 'Jagdgeschwader 1 (World War I)', 'Dogfight', 'Bloody April', 'Synchronization gear', 'Aviation', 'World War I', 'Sopwith Camel', 'Fokker Dr.I', 'Max Immelmann', 'Anthony Fokker', 'Jagdstaffel 2', 'Cavalry', 'National security', 'Triplane', 'Aerial warfare', 'Jagdstaffel 11', 'Conflicts', 'Reconnaissance']
# World War I 0.535
# val = 0.535
# row = 0 sentence_num = 199
# Phrase Number = 1
# ['Air forces', 'Air force', 'Royal Air Force']
# val = 0
# row = 1 sentence_num = 199
# Phrase Number = 2
# ['No. 209 Squadron RAF']
# val = 0
# row = 2 sentence_num = 199
# Phrase Number = 3
# ['Manfred von Richthofen', 'Fighter aircraft', 'Luftstreitkräfte', 'Cedric Popkin', 'Flying ace', 'Military', 'Military science', 'Military forces', 'Warfare', 'Military aviation', 'War', 'Aeronautics', 'Trench warfare', 'Aircraft', 'International security', 'Sopwith Aviation Company', 'Lanoe Hawker', 'Airplane', 'Aerospace engineering', 'Combat', 'Royal Flying Corps', 'Military organization', 'Violent conflict', 'Military operations']
# Manfred von Richthofen 1
# Military 0.5105
# val = 1.5105
# row = 3 sentence_num = 199
# Phrase Number = 4
# ['Imperial German Army Air Service']
# Imperial German Army Air Service 0.6013
# val = 0.6013
# row = 4 sentence_num = 199
# Phrase Number = 5
# ['Roy Brown (RAF officer)']
# val = 0
# row = 5 sentence_num = 199
# i =  400
# 400 ['On the other hand, he would not have survived as a kind of symbol for chivalrous warfare as he has in being killed.', "NARRATOR: With the new evidence about von Richthofen's death, we may be closer to the truth, but eyewitness testimony always leaves room for doubt."]
#   Culture 0.8749
#   Epistemology 0.8311
#   Evidence law 0.7798
#   Legal procedure 0.7558
#   Evidence 0.7285
#   Common law 0.7146
#   Witness 0.6769
#   Justice 0.6678
#   Justification 0.6581
#   Law 0.6337
#   Judiciaries 0.6178
#   Public law 0.5638
#   Social institutions 0.5263
# Phrase Number = 0
# ['Oswald Boelcke', 'Jagdstaffel', 'Jagdgeschwader 1 (World War I)', 'Dogfight', 'Bloody April', 'Synchronization gear', 'Aviation', 'World War I', 'Sopwith Camel', 'Fokker Dr.I', 'Max Immelmann', 'Anthony Fokker', 'Jagdstaffel 2', 'Cavalry', 'National security', 'Triplane', 'Aerial warfare', 'Jagdstaffel 11', 'Conflicts', 'Reconnaissance']
# val = 0
# row = 0 sentence_num = 200
# Phrase Number = 1
# ['Air forces', 'Air force', 'Royal Air Force']
# val = 0
# row = 1 sentence_num = 200
# Phrase Number = 2
# ['No. 209 Squadron RAF']
# val = 0
# row = 2 sentence_num = 200
# Phrase Number = 3
# ['Manfred von Richthofen', 'Fighter aircraft', 'Luftstreitkräfte', 'Cedric Popkin', 'Flying ace', 'Military', 'Military science', 'Military forces', 'Warfare', 'Military aviation', 'War', 'Aeronautics', 'Trench warfare', 'Aircraft', 'International security', 'Sopwith Aviation Company', 'Lanoe Hawker', 'Airplane', 'Aerospace engineering', 'Combat', 'Royal Flying Corps', 'Military organization', 'Violent conflict', 'Military operations']
# val = 0
# row = 3 sentence_num = 200
# Phrase Number = 4
# ['Imperial German Army Air Service']
# val = 0
# row = 4 sentence_num = 200
# Phrase Number = 5
# ['Roy Brown (RAF officer)']
# val = 0
# row = 5 sentence_num = 200
# i =  402
# 402 ["The circumstances surrounding the Baron's death will continue to be shrouded in mystery.", "DENNY MAY: I don't think that the world will ever know for sure who shot the Red Baron down."]
# Phrase Number = 0
# ['Oswald Boelcke', 'Jagdstaffel', 'Jagdgeschwader 1 (World War I)', 'Dogfight', 'Bloody April', 'Synchronization gear', 'Aviation', 'World War I', 'Sopwith Camel', 'Fokker Dr.I', 'Max Immelmann', 'Anthony Fokker', 'Jagdstaffel 2', 'Cavalry', 'National security', 'Triplane', 'Aerial warfare', 'Jagdstaffel 11', 'Conflicts', 'Reconnaissance']
# val = 0
# row = 0 sentence_num = 201
# Phrase Number = 1
# ['Air forces', 'Air force', 'Royal Air Force']
# val = 0
# row = 1 sentence_num = 201
# Phrase Number = 2
# ['No. 209 Squadron RAF']
# val = 0
# row = 2 sentence_num = 201
# Phrase Number = 3
# ['Manfred von Richthofen', 'Fighter aircraft', 'Luftstreitkräfte', 'Cedric Popkin', 'Flying ace', 'Military', 'Military science', 'Military forces', 'Warfare', 'Military aviation', 'War', 'Aeronautics', 'Trench warfare', 'Aircraft', 'International security', 'Sopwith Aviation Company', 'Lanoe Hawker', 'Airplane', 'Aerospace engineering', 'Combat', 'Royal Flying Corps', 'Military organization', 'Violent conflict', 'Military operations']
# val = 0
# row = 3 sentence_num = 201
# Phrase Number = 4
# ['Imperial German Army Air Service']
# val = 0
# row = 4 sentence_num = 201
# Phrase Number = 5
# ['Roy Brown (RAF officer)']
# val = 0
# row = 5 sentence_num = 201
# i =  404
# 404 ["That's a question that will go on in the minds of people for years and years and years.", 'NARRATOR: In death, Manfred von Richthofen became an icon of a period that saw the dawn of aerial combat and modern warfare.']
#   National security 1
#   Aviation 1
#   Military 1
#   War 1
#   Combat 1
#   Violent conflict 1
#   International security 1
#   Warfare 1
#   Military aviation 1
#   Conflicts 0.8815
#   Human rights abuses 0.8655
#   Military science 0.8185
#   Aerial warfare 0.754
#   Military forces 0.7475
#   Aeronautics 0.7297
#   Conflict (process) 0.6765
#   Hazards 0.6741
#   Manfred von Richthofen 0.5753
#   Defense 0.5739
#   Chronology of war 0.5596
#   Aerospace engineering 0.5275
#   Military operations 0.5262
#   Richthofen family 0.5166
# Phrase Number = 0
# ['Oswald Boelcke', 'Jagdstaffel', 'Jagdgeschwader 1 (World War I)', 'Dogfight', 'Bloody April', 'Synchronization gear', 'Aviation', 'World War I', 'Sopwith Camel', 'Fokker Dr.I', 'Max Immelmann', 'Anthony Fokker', 'Jagdstaffel 2', 'Cavalry', 'National security', 'Triplane', 'Aerial warfare', 'Jagdstaffel 11', 'Conflicts', 'Reconnaissance']
# National security 1
# Aviation 1
# Conflicts 0.8815
# Aerial warfare 0.754
# val = 3.6355
# row = 0 sentence_num = 202
# Phrase Number = 1
# ['Air forces', 'Air force', 'Royal Air Force']
# val = 0
# row = 1 sentence_num = 202
# Phrase Number = 2
# ['No. 209 Squadron RAF']
# val = 0
# row = 2 sentence_num = 202
# Phrase Number = 3
# ['Manfred von Richthofen', 'Fighter aircraft', 'Luftstreitkräfte', 'Cedric Popkin', 'Flying ace', 'Military', 'Military science', 'Military forces', 'Warfare', 'Military aviation', 'War', 'Aeronautics', 'Trench warfare', 'Aircraft', 'International security', 'Sopwith Aviation Company', 'Lanoe Hawker', 'Airplane', 'Aerospace engineering', 'Combat', 'Royal Flying Corps', 'Military organization', 'Violent conflict', 'Military operations']
# Military 1
# War 1
# Combat 1
# Violent conflict 1
# International security 1
# Warfare 1
# Military aviation 1
# Military science 0.8185
# Military forces 0.7475
# Aeronautics 0.7297
# Manfred von Richthofen 0.5753
# Aerospace engineering 0.5275
# Military operations 0.5262
# val = 10.9247
# row = 3 sentence_num = 202
# Phrase Number = 4
# ['Imperial German Army Air Service']
# val = 0
# row = 4 sentence_num = 202
# Phrase Number = 5
# ['Roy Brown (RAF officer)']
# val = 0
# row = 5 sentence_num = 202
# i =  406
# 406 ['His legend grew, not merely because of his 80 victories, a score which would not be beaten until World War II, but because his dashing career recalls a brief era of innovation and heroism, although it came at unthinkable cost to human life.', "SUZANNE FISCHER: I think the Red Baron's real achievement was his legacy of squadron tactics."]
#   War 0.6259
#   Military 0.6049
#   Violent conflict 0.5777
#   Warfare 0.5702
#   Military science 0.5444
#   Wars 0.5307
#   World War II 0.5211
#   International security 0.5033
# Phrase Number = 0
# ['Oswald Boelcke', 'Jagdstaffel', 'Jagdgeschwader 1 (World War I)', 'Dogfight', 'Bloody April', 'Synchronization gear', 'Aviation', 'World War I', 'Sopwith Camel', 'Fokker Dr.I', 'Max Immelmann', 'Anthony Fokker', 'Jagdstaffel 2', 'Cavalry', 'National security', 'Triplane', 'Aerial warfare', 'Jagdstaffel 11', 'Conflicts', 'Reconnaissance']
# val = 0
# row = 0 sentence_num = 203
# Phrase Number = 1
# ['Air forces', 'Air force', 'Royal Air Force']
# val = 0
# row = 1 sentence_num = 203
# Phrase Number = 2
# ['No. 209 Squadron RAF']
# val = 0
# row = 2 sentence_num = 203
# Phrase Number = 3
# ['Manfred von Richthofen', 'Fighter aircraft', 'Luftstreitkräfte', 'Cedric Popkin', 'Flying ace', 'Military', 'Military science', 'Military forces', 'Warfare', 'Military aviation', 'War', 'Aeronautics', 'Trench warfare', 'Aircraft', 'International security', 'Sopwith Aviation Company', 'Lanoe Hawker', 'Airplane', 'Aerospace engineering', 'Combat', 'Royal Flying Corps', 'Military organization', 'Violent conflict', 'Military operations']
# War 0.6259
# Military 0.6049
# Violent conflict 0.5777
# Warfare 0.5702
# Military science 0.5444
# International security 0.5033
# val = 3.4264
# row = 3 sentence_num = 203
# Phrase Number = 4
# ['Imperial German Army Air Service']
# val = 0
# row = 4 sentence_num = 203
# Phrase Number = 5
# ['Roy Brown (RAF officer)']
# val = 0
# row = 5 sentence_num = 203
# i =  408
# 408 ["And it wasn't just that he developed them, but he actually wrote them down so that people could use them and still do use them today.", 'His other achievement was his love of technology and pushing to get the best aircraft produced as quickly as possible.']
# Phrase Number = 0
# ['Oswald Boelcke', 'Jagdstaffel', 'Jagdgeschwader 1 (World War I)', 'Dogfight', 'Bloody April', 'Synchronization gear', 'Aviation', 'World War I', 'Sopwith Camel', 'Fokker Dr.I', 'Max Immelmann', 'Anthony Fokker', 'Jagdstaffel 2', 'Cavalry', 'National security', 'Triplane', 'Aerial warfare', 'Jagdstaffel 11', 'Conflicts', 'Reconnaissance']
# val = 0
# row = 0 sentence_num = 204
# Phrase Number = 1
# ['Air forces', 'Air force', 'Royal Air Force']
# val = 0
# row = 1 sentence_num = 204
# Phrase Number = 2
# ['No. 209 Squadron RAF']
# val = 0
# row = 2 sentence_num = 204
# Phrase Number = 3
# ['Manfred von Richthofen', 'Fighter aircraft', 'Luftstreitkräfte', 'Cedric Popkin', 'Flying ace', 'Military', 'Military science', 'Military forces', 'Warfare', 'Military aviation', 'War', 'Aeronautics', 'Trench warfare', 'Aircraft', 'International security', 'Sopwith Aviation Company', 'Lanoe Hawker', 'Airplane', 'Aerospace engineering', 'Combat', 'Royal Flying Corps', 'Military organization', 'Violent conflict', 'Military operations']
# val = 0
# row = 3 sentence_num = 204
# Phrase Number = 4
# ['Imperial German Army Air Service']
# val = 0
# row = 4 sentence_num = 204
# Phrase Number = 5
# ['Roy Brown (RAF officer)']
# val = 0
# row = 5 sentence_num = 204
# i =  410
# 410 ['NARRATOR: In four short years, aerial combat had evolved from an amateurish sport to a deadly efficient killing operation.', "But now the evidence of von Richthofen's death suggests a final irony."]
# Phrase Number = 0
# ['Oswald Boelcke', 'Jagdstaffel', 'Jagdgeschwader 1 (World War I)', 'Dogfight', 'Bloody April', 'Synchronization gear', 'Aviation', 'World War I', 'Sopwith Camel', 'Fokker Dr.I', 'Max Immelmann', 'Anthony Fokker', 'Jagdstaffel 2', 'Cavalry', 'National security', 'Triplane', 'Aerial warfare', 'Jagdstaffel 11', 'Conflicts', 'Reconnaissance']
# val = 0
# row = 0 sentence_num = 205
# Phrase Number = 1
# ['Air forces', 'Air force', 'Royal Air Force']
# val = 0
# row = 1 sentence_num = 205
# Phrase Number = 2
# ['No. 209 Squadron RAF']
# val = 0
# row = 2 sentence_num = 205
# Phrase Number = 3
# ['Manfred von Richthofen', 'Fighter aircraft', 'Luftstreitkräfte', 'Cedric Popkin', 'Flying ace', 'Military', 'Military science', 'Military forces', 'Warfare', 'Military aviation', 'War', 'Aeronautics', 'Trench warfare', 'Aircraft', 'International security', 'Sopwith Aviation Company', 'Lanoe Hawker', 'Airplane', 'Aerospace engineering', 'Combat', 'Royal Flying Corps', 'Military organization', 'Violent conflict', 'Military operations']
# val = 0
# row = 3 sentence_num = 205
# Phrase Number = 4
# ['Imperial German Army Air Service']
# val = 0
# row = 4 sentence_num = 205
# Phrase Number = 5
# ['Roy Brown (RAF officer)']
# val = 0
# row = 5 sentence_num = 205
# i =  412
# 412 ['If he indeed was killed in action by an old fashioned gun from the ground, the Red Baron may never have lost a dogfight.']
#   Military aviation 0.7281
#   Aviation 0.6273
#   Combat 0.5876
#   Aerial warfare 0.5659
#   Military 0.5016
# Phrase Number = 0
# ['Oswald Boelcke', 'Jagdstaffel', 'Jagdgeschwader 1 (World War I)', 'Dogfight', 'Bloody April', 'Synchronization gear', 'Aviation', 'World War I', 'Sopwith Camel', 'Fokker Dr.I', 'Max Immelmann', 'Anthony Fokker', 'Jagdstaffel 2', 'Cavalry', 'National security', 'Triplane', 'Aerial warfare', 'Jagdstaffel 11', 'Conflicts', 'Reconnaissance']
# Aviation 0.6273
# Aerial warfare 0.5659
# val = 1.1932
# row = 0 sentence_num = 206
# Phrase Number = 1
# ['Air forces', 'Air force', 'Royal Air Force']
# val = 0
# row = 1 sentence_num = 206
# Phrase Number = 2
# ['No. 209 Squadron RAF']
# val = 0
# row = 2 sentence_num = 206
# Phrase Number = 3
# ['Manfred von Richthofen', 'Fighter aircraft', 'Luftstreitkräfte', 'Cedric Popkin', 'Flying ace', 'Military', 'Military science', 'Military forces', 'Warfare', 'Military aviation', 'War', 'Aeronautics', 'Trench warfare', 'Aircraft', 'International security', 'Sopwith Aviation Company', 'Lanoe Hawker', 'Airplane', 'Aerospace engineering', 'Combat', 'Royal Flying Corps', 'Military organization', 'Violent conflict', 'Military operations']
# Military aviation 0.7281
# Combat 0.5876
# Military 0.5016
# val = 1.8173000000000001
# row = 3 sentence_num = 206
# Phrase Number = 4
# ['Imperial German Army Air Service']
# val = 0
# row = 4 sentence_num = 206
# Phrase Number = 5
# ['Roy Brown (RAF officer)']
# val = 0
# row = 5 sentence_num = 206
# Output files: output_ws2.csv no_cluster_dict_ws2.csv
# Saved ggplot

# %%
df_filter.groupby("id").sum().sort_values('value', ascending=False)
# Out:
#                                   value
# id
# Military                             47
# Jagdstaffel                          45
# Imperial German Army Air Service     18
# Air forces                            7
# No. 209 Squadron RAF                  1
# Roy Brown (RAF officer)               1

# %%
list(df_filter.groupby("id").sum().sort_values('value', ascending=False).index.values)
# Out:
# ['Military',
#  'Jagdstaffel',
#  'Imperial German Army Air Service',
#  'Air forces',
#  'No. 209 Squadron RAF',
#  'Roy Brown (RAF officer)']

# %%
df_filter = df_new_max.loc[df_new_max['value'] != 0]
#ggplot(aes(x='variable', y='id', color='id'), data=df_new_max.loc[df_new_max['value'] != 0])  + geom_line()
import matplotlib.pyplot as plot
#fig, ax = plot.subplots()
#colordict =
#df_new.plot(x="variable", y = "value", c = "C0",)
plot.figure(figsize=(20,10))

ylabel = list(df_filter.groupby("id").sum().sort_values('value', ascending=False).index.values)
#plot.yticks(range(len(ylabel)), ylabel, horizontalalignment='right', weight='bold', size='large')
#plot.set_yticklabels(ylabel)
#plot.xticks(x, my_xticks)
#plot.yticks(ylabel)

#ax.set_yticklabels(ylabel)
plot.scatter(df_filter.variable, df_filter.id,alpha = 1, s = 15)

plot.show()

# %%
ggplot(aes(x='variable', y='value', color='id'), data=df_new_max)  + geom_hist()
# Out:
# <ggplot: (137900500551)>

# %%
ggplot(aes(x='variable', y='value', color='id'), data=df_new)  + geom_line()  +  facet_wrap("id")
# Out:
# <ggplot: (137899289864)>
